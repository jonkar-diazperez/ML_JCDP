# %% [markdown]
# # Importar Datasets AEMET

# %%
import pandas as pd
import numpy as np
import requests
import json

# %%
df_aemet = pd.read_csv("../data/raw/AEMET/AEMET Radiación DATOS.txt", sep=';', header=2)
df_aemet
# Out:
#                         Estación Indicativo Tipo  5  6  7   8    9   10   11  \
# 0                       A Coruña       1387   GL  0  0  0   5   24   69   59
# 1                       Albacete      8178D   GL  1  1  1   4   18   50  111
# 2             Almería Aeropuerto      6325O   GL  0  0  0  20   50   71  143
# 3                        Badajoz      4478G   GL  0  0  0  12   65  120  159
# 4                      Barcelona      0201D   GL  0  0  0   5   48   87  141
# 5                        Cáceres      3469A   GL  0  0  0   8   62  117  156
# 6                          Cádiz       5973   GL  0  0  0  17   74  134  180
# 7                    Ciudad Real       4121   GL  0  0  0   2   35  108  144
# 8             Córdoba Aeropuerto       5402   GL  0  0  0   4   47  127  150
# 9                        Granada       5514   GL  0  0  0   4   16   41   37
# 10                        Huelva      4642E   GL  0  0  0  16   71  125  167
# ...

# %% [markdown]
# ## API REE

# %%
df_solar_w = pd.DataFrame()
for i in [2023,2024,2025]:
    ree_url ="https://apidatos.ree.es"
    path_renov = "/es/datos/generacion/estructura-renovables"
    ree_api_param = f"?start_date={i}-01-01T00:00&end_date={i}-12-31T23:59&time_trunc=month&geo_limit=ccaa&all_ccaa=allCcaa&tecno_select=1458&widget=estructura-renovables"

    api_ree_url = ree_url + path_renov + ree_api_param

    print(api_ree_url)

    response = requests.get(api_ree_url)

    if response.status_code == 200:  # Código 200 indica una respuesta exitosa.
        data = response.json()
        print(data)
        df_solar_w = pd.concat([df_solar_w, pd.DataFrame(data["included"])[:-1]],ignore_index=True)

        
    else:
        print("Error en la solicitud: ", response.status_code)
        
print(df_solar_w)
# Out:
# https://apidatos.ree.es/es/datos/generacion/estructura-renovables?start_date=2023-01-01T00:00&end_date=2023-12-31T23:59&time_trunc=month&geo_limit=ccaa&all_ccaa=allCcaa&tecno_select=1458&widget=estructura-renovables
# ...

# %%
#df_solar_w.reindex()
df_solar_w
# Out:
#    geo_id          community_name  \
# 0       4               Andalucía
# 1       5                  Aragón
# 2      11  Principado de Asturias
# 3       6               Cantabria
# 4       7     Castilla- La Mancha
# 5       8         Castilla y León
# 6       9                Cataluña
# 7      12         Comunidad Ceuta
# 8      13     Comunidad de Madrid
# 9      15    Comunidad Valenciana
# 10     16             Extremadura
# 11     17                 Galicia
# 12     18          Islas Baleares
# 13     19          Islas Canarias
# 14     20                La Rioja
# 15   8746       Comunidad Melilla
# 16     21        Región de Murcia
# 17     14    Comunidad de Navarra
# 18     10              País Vasco
# 19      4               Andalucía
# 20      5                  Aragón
# 21     11  Principado de Asturias
# 22      6               Cantabria
# 23      7     Castilla- La Mancha
# 24      8         Castilla y León
# 25      9                Cataluña
# ...

# %%
data
# Out:
# {'data': {'type': 'Generación por tecnología renovable',
#   'id': 'gen3',
#   'attributes': {'title': 'Generación por tecnología renovable',
#    'last-update': '2025-12-09T23:45:54.000+01:00',
#    'description': None},
#   'meta': {'cache-control': {'cache': 'MISS'}}},
#  'included': [{'geo_id': 4,
#    'community_name': 'Andalucía',
#    'content': [{'type': 'Hidráulica',
#      'id': '10330',
#      'groupId': '1',
#      'attributes': {'title': 'Hidráulica',
#       'description': 'Hidráulica: no incluye la generación bombeo.',
#       'color': '#0090d1',
#       'icon': None,
#       'type': None,
#       'magnitude': None,
#       'composite': False,
#       'last-update': '2025-08-20T18:35:04.000+02:00',
#       'values': [{'value': 14475.259,
#         'percentage': 0.010923851448396943,
#         'datetime': '2025-01-01T00:00:00.000+01:00'},
#        {'value': 9207.406,
#         'percentage': 0.00665403926818653,
#         'datetime': '2025-02-01T00:00:00.000+01:00'},
# ...

# %%
#len(data["included"])

# %%
#df_solar_w = pd.DataFrame(data["included"])
df_solar_w
# Out:
#    geo_id          community_name  \
# 0       4               Andalucía
# 1       5                  Aragón
# 2      11  Principado de Asturias
# 3       6               Cantabria
# 4       7     Castilla- La Mancha
# 5       8         Castilla y León
# 6       9                Cataluña
# 7      12         Comunidad Ceuta
# 8      13     Comunidad de Madrid
# 9      15    Comunidad Valenciana
# 10     16             Extremadura
# 11     17                 Galicia
# 12     18          Islas Baleares
# 13     19          Islas Canarias
# 14     20                La Rioja
# 15   8746       Comunidad Melilla
# 16     21        Región de Murcia
# 17     14    Comunidad de Navarra
# 18     10              País Vasco
# 19      4               Andalucía
# 20      5                  Aragón
# 21     11  Principado de Asturias
# 22      6               Cantabria
# 23      7     Castilla- La Mancha
# 24      8         Castilla y León
# 25      9                Cataluña
# ...

# %%
#df_solar_w = df_solar_w[:-1]

# %%
data["included"][0]["content"]["attributes"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data["included"][0]["content"]["attributes"]
#
# TypeError: list indices must be integers or slices, not str

# %%
df_solar_w["content"]
# Out:
# 0     [{'type': 'Hidráulica', 'id': '10330', 'groupI...
# 1     [{'type': 'Hidráulica', 'id': '10330', 'groupI...
# 2     [{'type': 'Hidráulica', 'id': '10330', 'groupI...
# 3     [{'type': 'Hidráulica', 'id': '10330', 'groupI...
# 4     [{'type': 'Hidráulica', 'id': '10330', 'groupI...
# 5     [{'type': 'Hidráulica', 'id': '10330', 'groupI...
# 6     [{'type': 'Hidráulica', 'id': '10330', 'groupI...
# 7     [{'type': 'Solar fotovoltaica', 'id': '1707', ...
# 8     [{'type': 'Hidráulica', 'id': '10330', 'groupI...
# 9     [{'type': 'Hidráulica', 'id': '10330', 'groupI...
# 10    [{'type': 'Hidráulica', 'id': '10330', 'groupI...
# 11    [{'type': 'Hidráulica', 'id': '10330', 'groupI...
# 12    [{'type': 'Eólica', 'id': '10333', 'groupId': ...
# 13    [{'type': 'Hidráulica', 'id': '10330', 'groupI...
# 14    [{'type': 'Hidráulica', 'id': '10330', 'groupI...
# 15    [{'type': 'Solar fotovoltaica', 'id': '1707', ...
# 16    [{'type': 'Hidráulica', 'id': '10330', 'groupI...
# ...

# %%
df_solar_w.loc[1]['geo_id']
# Out:
# 5

# %%
reg = []
for i in df_solar_w.index:
    print(i, "geo_id: ", df_solar_w.loc[i]['geo_id'], "Comunidad: ", df_solar_w.loc[i]['community_name'])
    content = df_solar_w.loc[i]["content"]
    for c in content:
        if c['type'] == 'Solar fotovoltaica':
            for v in c['attributes']['values']:
                print(v['value'], v['datetime'][0:4], v['datetime'][5:7])
                r = [df_solar_w.loc[i]['geo_id'],
                    df_solar_w.loc[i]['community_name'],
                    v['datetime'][0:4],
                    v['datetime'][5:7],
                    round(v['value'],2)
                    ]
                print(r)
                reg.append(r)
                
    df_solar = pd.DataFrame(reg,columns=['geo_id', 'Comunidad', 'Año', 'Mes', 'Energía Solar'])
# Out:
# 0 geo_id:  4 Comunidad:  Andalucía
# 429269.28 2023 01
# [4, 'Andalucía', '2023', '01', 429269.28]
# 471628.414 2023 02
# [4, 'Andalucía', '2023', '02', 471628.41]
# 728490.931 2023 03
# [4, 'Andalucía', '2023', '03', 728490.93]
# 849844.867 2023 04
# [4, 'Andalucía', '2023', '04', 849844.87]
# 836786.208 2023 05
# [4, 'Andalucía', '2023', '05', 836786.21]
# 892010.71 2023 06
# [4, 'Andalucía', '2023', '06', 892010.71]
# 1020039.276 2023 07
# [4, 'Andalucía', '2023', '07', 1020039.28]
# 947918.311 2023 08
# [4, 'Andalucía', '2023', '08', 947918.31]
# 767192.797 2023 09
# [4, 'Andalucía', '2023', '09', 767192.8]
# 603256.874 2023 10
# [4, 'Andalucía', '2023', '10', 603256.87]
# 496101.24 2023 11
# [4, 'Andalucía', '2023', '11', 496101.24]
# 458843.053 2023 12
# [4, 'Andalucía', '2023', '12', 458843.05]
# 1 geo_id:  5 Comunidad:  Aragón
# 142219.179 2023 01
# [5, 'Aragón', '2023', '01', 142219.18]
# 206100.924 2023 02
# [5, 'Aragón', '2023', '02', 206100.92]
# 312663.144 2023 03
# ...

# %%
df_solar
# Out:
#      geo_id   Comunidad   Año Mes  Energía Solar
# 0         4   Andalucía  2023  01      429269.28
# 1         4   Andalucía  2023  02      471628.41
# 2         4   Andalucía  2023  03      728490.93
# 3         4   Andalucía  2023  04      849844.87
# 4         4   Andalucía  2023  05      836786.21
# ..      ...         ...   ...  ..            ...
# 632      10  País Vasco  2025  07        8708.41
# 633      10  País Vasco  2025  08        7917.38
# 634      10  País Vasco  2025  09        6629.45
# 635      10  País Vasco  2025  10        5277.86
# 636      10  País Vasco  2025  11        2535.24
#
# [637 rows x 5 columns]

# %%
df_solar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 637 entries, 0 to 636
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   geo_id         637 non-null    int64
#  1   Comunidad      637 non-null    object
#  2   Año            637 non-null    object
#  3   Mes            637 non-null    object
#  4   Energía Solar  637 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 25.0+ KB

# %%
df_solar.to_csv("../data/raw/REE/Solar fotovoltaica.csv")

# %% [markdown]
# ## API AEMET

# %%
aemet_url ="https://opendata.aemet.es/opendata"
path_aemet = "/api/valores/climatologicos/mensualesanuales/datos/anioini/2023/aniofin/2025/estacion/"
est_param = df_aemet_rad["Indicativo"][1]

api_aemet_url = aemet_url + path_aemet + est_param
print(api_aemet_url)
response = requests.get(api_aemet_url)
print(response)

if response.status_code == 200:  # Código 200 indica una respuesta exitosa.
    #data = response.json()  # Analizar la respuesta JSON.
    print(response.links)
    print(response.content)
    print(response.iter_content())

    aemet_data = requests.get(data)
    print(aemet_data.content)
else:
    print("Error en la solicitud: ", response.status_code)
# Out:
# https://opendata.aemet.es/opendata/api/valores/climatologicos/mensualesanuales/datos/anioini/2023/aniofin/2025/estacion/8178D
# <Response [200]>
# {}
# b''
# <generator object iter_slices at 0x0000024B808EA7A0>
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[36], line 16
#      13     print(response.content)
#      14     print(response.iter_content())
# ---> 16     aemet_data = requests.get(data)
#      17     print(aemet_data.content)
#      18 else:
#
# File c:\Users\atosj\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ...

# %%
response
# Out:
# <Response [200]>

# %%
data = response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\atosj\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\atosj\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
data["datos"]
# Out:
# 'https://opendata.aemet.es/opendata/sh/37fc4181'

# %%
datos_estacion = data["datos"].read

# %%
json = {
  "descripcion": "exito",
  "estado": 200,
  "datos": "https://opendata.aemet.es/opendata/sh/d666e78c",
  "metadatos": "https://opendata.aemet.es/opendata/sh/9b311421"
}

# %%
json["datos"]
# Out:
# 'https://opendata.aemet.es/opendata/sh/d666e78c'

# %%
response = requests.get(json["datos"])
response.content
# Out:
# b'<!DOCTYPE html><html><head><title>Apache Tomcat/8.0.32 - Error report</title><style type="text/css">H1 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:22px;} H2 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:16px;} H3 {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;font-size:14px;} BODY {font-family:Tahoma,Arial,sans-serif;color:black;background-color:white;} B {font-family:Tahoma,Arial,sans-serif;color:white;background-color:#525D76;} P {font-family:Tahoma,Arial,sans-serif;background:white;color:black;font-size:12px;}A {color : black;}A.name {color : black;}.line {height: 1px; background-color: #525D76; border: none;}</style> </head><body><h1>HTTP Status 500 - 429 Too Many Requests: &quot;{&lt;EOL&gt;  &quot;descripcion&quot; : &quot;L\xef\xbf\xbdmite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.&quot;,&lt;EOL&gt;  &quot;estado&quot; : 429&
# ...

# %%
df_aemet_rad = pd.read_csv("../data/raw/AEMET/AEMET Radiación DATOS.txt", sep=";", header=2)

# %%
df_aemet_rad
# Out:
#                         Estación Indicativo Tipo  5  6  7   8    9   10   11  \
# 0                       A Coruña       1387   GL  0  0  0   5   24   69   59
# 1                       Albacete      8178D   GL  1  1  1   4   18   50  111
# 2             Almería Aeropuerto      6325O   GL  0  0  0  20   50   71  143
# 3                        Badajoz      4478G   GL  0  0  0  12   65  120  159
# 4                      Barcelona      0201D   GL  0  0  0   5   48   87  141
# 5                        Cáceres      3469A   GL  0  0  0   8   62  117  156
# 6                          Cádiz       5973   GL  0  0  0  17   74  134  180
# 7                    Ciudad Real       4121   GL  0  0  0   2   35  108  144
# 8             Córdoba Aeropuerto       5402   GL  0  0  0   4   47  127  150
# 9                        Granada       5514   GL  0  0  0   4   16   41   37
# 10                        Huelva      4642E   GL  0  0  0  16   71  125  167
# ...

# %%
df_aemet_rad["Indicativo"].to_csv("../data/raw/AEMET/Lista estaciones radiación.csv", index=False)

# %%
for i in df_aemet_rad["Indicativo"]:
    aemet_url ="https://opendata.aemet.es/opendata"
    path_aemet = "/api/valores/climatologicos/mensualesanuales/datos/anioini/2023/aniofin/2025/estacion/"
    est_param = df_aemet_rad["Indicativo"][0]

    api_aemet_url = aemet_url + path_aemet + est_param

    response = requests.get(api_aemet_url)
    response

    if response.status_code == 200:  # Código 200 indica una respuesta exitosa.
        #data = response.json()  # Analizar la respuesta JSON.
        #print(data["datos"])
        print(response.content)
        aemet_data = requests.get(response.content["datos"])
        print(aemet_data.content)
    else:
            print("Error en la solicitud: ", response.status_code)
# Out:
# b''
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 15
#      11 if response.status_code == 200:  # Código 200 indica una respuesta exitosa.
#      12     #data = response.json()  # Analizar la respuesta JSON.
#      13     #print(data["datos"])
#      14     print(response.content)
# ---> 15     aemet_data = requests.get(response.content["datos"])
#      16     print(aemet_data.content)
#      17 else:
#
# TypeError: byte indices must be integers or slices, not str

# %%
df_aemet_lcg = pd.read_csv("../data/raw/AEMET/AEMET Coruña DATOS Anuales.txt")
df_aemet_lcg
# Out:
#                          [ {
#   "indicativo" : "1387"  NaN
#   "p_max" : "32.6(19)"   NaN
#   "n_cub" : "11"         NaN
#   "glo" : "28536"        NaN
#   "hr" : "75"            NaN
# ...                      ...
#   "nv_0100" : "0"        NaN
#   "q_min" : "986.1(13)"  NaN
#   "np_010" : "19"        NaN
#   "fecha" : "2025-11"    NaN
# } ]                      NaN
#
# [1695 rows x 1 columns]

# %%
#df_aemet_tor = pd.read_json('../data/raw/AEMET/AEMET TOR DATOS Anuales.csv')
df_aemet_tor = pd.read_json('../data/raw/AEMET/AEMET TOR DATOS Anuales.txt', orient='records')
df_aemet_tor
# Out:
#    indicativo          p_max       glo    hr  n_gra  n_fog  inso  \
# 0       9981A        6.4(19)   39273.0  69.0    0.0    3.0   7.0
# 1       9981A        5.4(02)   27203.0  58.0    1.0    2.0   6.5
# 2       9981A        6.4(07)   23544.0  58.0    0.0    1.0   6.3
# 3       9981A  105.8(02/sep)       NaN  58.0    7.0    8.0   8.1
# 4       9981A        2.8(17)       NaN  55.0    0.0    0.0   6.9
# 5       9981A       39.8(07)       NaN  63.0    0.0    1.0   6.9
# 6       9981A        5.4(09)       NaN  56.0    0.0    0.0   8.2
# 7       9981A        3.6(29)   65196.0  51.0    0.0    0.0  10.0
# 8       9981A       42.8(25)   73611.0  50.0    3.0    1.0   9.7
# 9       9981A       30.2(03)   69395.0  60.0    0.0    0.0   8.7
# 10      9981A        3.2(04)   70246.0  58.0    0.0    0.0   8.5
# 11      9981A       13.0(26)   73007.0  51.0    1.0    0.0  10.8
# 12      9981A      105.8(02)   49648.0  72.0    2.0    0.0   7.9
# ...

# %%
df_aemet_raw = pd.read_json('../data/raw/AEMET/AEMET Estaciones DATOS Anuales.json', orient='records')

df_aemet_raw
# Out:
#      indicativo         p_max  n_cub       glo    hr  n_gra  n_fog  inso  \
# 0          1387      32.6(19)   11.0   28536.0  75.0    1.0    5.0   4.7
# 1          1387      36.4(05)   12.0   16599.0  80.0    0.0    3.0   3.0
# 2          1387      56.8(27)    8.0   14628.0  77.0    0.0    0.0   3.0
# 3          1387  56.8(27/dic)   83.0  533752.0  74.0    4.0   29.0   6.7
# 4          1387      22.0(19)   11.0   17949.0  76.0    1.0    0.0   3.9
# ...         ...           ...    ...       ...   ...    ...    ...   ...
# 1399       9434       8.0(03)    2.0       NaN  43.0    0.0    0.0  11.6
# 1400       9434      10.4(11)    1.0       NaN  46.0    0.0    0.0  11.8
# 1401       9434       7.8(27)    0.0       NaN  45.0    0.0    0.0  10.9
# 1402       9434      19.6(28)    2.0       NaN  53.0    0.0    0.0   9.5
# 1403       9434      12.4(05)    5.0       NaN  68.0    0.0    0.0   5.9
#
#                q_max  nw_55  ...  nt_00  ti_max  n_nie tm_mes  tm_max  \
# ...

# %%
df_aemet_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1404 entries, 0 to 1403
# Data columns (total 46 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   indicativo  1404 non-null   object
#  1   p_max       1296 non-null   object
#  2   n_cub       1059 non-null   float64
#  3   glo         1097 non-null   float64
#  4   hr          1241 non-null   float64
#  5   n_gra       998 non-null    float64
#  6   n_fog       998 non-null    float64
#  7   inso        1004 non-null   float64
#  8   q_max       1153 non-null   object
#  9   nw_55       1220 non-null   float64
#  10  q_mar       1152 non-null   float64
#  11  q_med       1154 non-null   float64
#  12  tm_min      1261 non-null   float64
#  13  ta_max      1261 non-null   object
#  14  ts_min      1261 non-null   float64
#  15  nt_30       1261 non-null   float64
#  16  nv_0050     938 non-null    float64
#  17  n_des       1059 non-null   float64
# ...

# %%
df_aemet_fechas = df_aemet_raw["fecha"].str.split('-', expand=True)

# %%
df_aemet_raw["Año"] = df_aemet_fechas[0]

# %%
df_aemet_raw["Mes"] = df_aemet_fechas[1]

# %%
df_aemet_raw
# Out:
#      indicativo         p_max  n_cub       glo    hr  n_gra  n_fog  inso  \
# 0          1387      32.6(19)   11.0   28536.0  75.0    1.0    5.0   4.7
# 1          1387      36.4(05)   12.0   16599.0  80.0    0.0    3.0   3.0
# 2          1387      56.8(27)    8.0   14628.0  77.0    0.0    0.0   3.0
# 3          1387  56.8(27/dic)   83.0  533752.0  74.0    4.0   29.0   6.7
# 4          1387      22.0(19)   11.0   17949.0  76.0    1.0    0.0   3.9
# ...         ...           ...    ...       ...   ...    ...    ...   ...
# 1399       9434       8.0(03)    2.0       NaN  43.0    0.0    0.0  11.6
# 1400       9434      10.4(11)    1.0       NaN  46.0    0.0    0.0  11.8
# 1401       9434       7.8(27)    0.0       NaN  45.0    0.0    0.0  10.9
# 1402       9434      19.6(28)    2.0       NaN  53.0    0.0    0.0   9.5
# 1403       9434      12.4(05)    5.0       NaN  68.0    0.0    0.0   5.9
#
#                q_max  nw_55  ...  n_nie  tm_mes  tm_max nv_0100  ts_50  \
# ...

# %%
#df_aemet_raw.to_csv("../data/raw/pred_solar.csv", index=False)

# %%
df_aemet_raw[df_aemet_raw["indicativo"] == '1111X'][["glo","fecha"]]
# Out:
#       glo    fecha
# 1053  NaN  2023-10
# 1054  NaN  2023-11
# 1055  NaN  2023-13
# 1056  NaN  2023-12
# 1057  NaN   2023-2
# 1058  NaN   2023-1
# 1059  NaN   2023-3
# 1060  NaN   2023-4
# 1061  NaN   2023-6
# 1062  NaN   2023-7
# 1063  NaN   2023-5
# 1064  NaN   2023-9
# 1065  NaN   2023-8
# 1066  NaN  2024-11
# 1067  NaN  2024-10
# 1068  NaN  2024-12
# 1069  NaN   2024-1
# 1070  NaN  2024-13
# 1071  NaN   2024-2
# 1072  NaN   2024-3
# 1073  NaN   2024-4
# 1074  NaN   2024-6
# 1075  NaN   2024-5
# 1076  NaN   2024-7
# 1077  NaN   2024-8
# 1078  NaN  2025-10
# 1079  NaN   2024-9
# 1080  NaN  2025-12
# 1081  NaN  2025-13
# 1082  NaN   2025-1
# 1083  NaN   2025-2
# 1084  NaN   2025-3
# 1085  NaN   2025-4
# 1086  NaN   2025-6
# 1087  NaN   2025-5
# 1088  NaN   2025-7
# 1089  NaN   2025-8
# 1090  NaN   2025-9
# 1091  NaN  2025-11

# %%
df_aemet_san_glo = pd.read_json('../data/raw/AEMET/AEMET SAN GLO DATOS Anuales.txt', orient='records')
df_aemet_san_glo
# Out:
#     indicativo         p_max  n_cub      glo  n_gra  n_fog  inso  \
# 0         1111      21.5(13)   12.0  29913.0    0.0    3.0   5.4
# 1         1111      33.8(27)   15.0  15762.0    0.0    2.0   3.1
# 2         1111      18.9(01)   13.0      NaN    0.0    0.0   3.4
# 3         1111  88.6(16/ene)  133.0      NaN    2.0   12.0   5.7
# 4         1111      47.3(22)   10.0      NaN    1.0    0.0   5.6
# 5         1111      88.6(16)   11.0  14315.0    1.0    0.0   3.4
# 6         1111      17.7(11)   13.0  40408.0    0.0    0.0   5.6
# 7         1111      10.5(23)   13.0  52955.0    0.0    3.0   6.4
# 8         1111      14.1(11)   10.0  62832.0    0.0    2.0   7.2
# 9         1111       9.9(29)   12.0  60083.0    0.0    1.0   7.0
# 10        1111       8.4(23)   10.0  60476.0    0.0    0.0   7.1
# 11        1111      18.4(26)    9.0  55108.0    0.0    1.0   7.0
# 12        1111      60.8(11)    5.0  42069.0    0.0    0.0   7.0
# ...

# %%
df_aemet_san_glo[["glo","fecha"]]
# Out:
#         glo    fecha
# 0   29913.0  2023-10
# 1   15762.0  2023-11
# 2       NaN  2023-12
# 3       NaN  2023-13
# 4       NaN   2023-2
# 5   14315.0   2023-1
# 6   40408.0   2023-3
# 7   52955.0   2023-4
# 8   62832.0   2023-5
# 9   60083.0   2023-6
# 10  60476.0   2023-7
# 11  55108.0   2023-8
# 12  42069.0   2023-9
# 13      NaN  2024-10
# 14  20986.0  2024-11
# 15  15777.0  2024-12
# 16      NaN  2024-13
# 17  18625.0   2024-1
# 18  22018.0   2024-2
# 19  37282.0   2024-3
# 20  53338.0   2024-4
# 21  58343.0   2024-5
# 22  43421.0   2024-6
# 23      NaN   2024-8
# 24  56523.0   2024-7
# 25      NaN   2024-9
# 26  36151.0  2025-10
# 27      NaN  2025-12
# 28      NaN  2025-13
# 29  18486.0   2025-1
# 30  38395.0   2025-3
# 31  26174.0   2025-2
# 32  53654.0   2025-4
# 33  57657.0   2025-5
# 34  57230.0   2025-6
# 35  61228.0   2025-7
# 36  53277.0   2025-8
# 37  44354.0   2025-9
# 38  17110.0  2025-11

# %%
df_aemet_san_glo[df_aemet_raw["fecha"] == df_aemet_san_glo["fecha"]]["glo"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 df_aemet_san_glo[df_aemet_raw["fecha"] == df_aemet_san_glo["fecha"]]["glo"]
#
# File c:\Users\atosj\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\atosj\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Users\atosj\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6133, in Series._cmp_method(self, other, op)
# ...

# %%
df_aemet_raw[df_aemet_raw["indicativo"] == '1111X']["glo"] = df_aemet_san_glo[["glo"]]
# Out:
# C:\Users\atosj\AppData\Local\Temp\ipykernel_3592\3432681959.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aemet_raw[df_aemet_raw["indicativo"] == '1111X']["glo"] = df_aemet_san_glo[["glo"]]

# %%
df_aemet_raw.loc[df_aemet_raw["indicativo"] == '1111X',"glo"] = df_aemet_san_glo["glo"]

# %%
df_aemet_san_glo["glo"]
# Out:
# 0     29913.0
# 1     15762.0
# 2         NaN
# 3         NaN
# 4         NaN
# 5     14315.0
# 6     40408.0
# 7     52955.0
# 8     62832.0
# 9     60083.0
# 10    60476.0
# 11    55108.0
# 12    42069.0
# 13        NaN
# 14    20986.0
# 15    15777.0
# 16        NaN
# 17    18625.0
# 18    22018.0
# 19    37282.0
# 20    53338.0
# 21    58343.0
# 22    43421.0
# 23        NaN
# 24    56523.0
# 25        NaN
# 26    36151.0
# 27        NaN
# 28        NaN
# 29    18486.0
# 30    38395.0
# 31    26174.0
# 32    53654.0
# 33    57657.0
# 34    57230.0
# 35    61228.0
# 36    53277.0
# 37    44354.0
# 38    17110.0
# Name: glo, dtype: float64

# %%
df_aemet_raw[df_aemet_raw["indicativo"] == '1111X']
# Out:
#      indicativo         p_max  n_cub  glo    hr  n_gra  n_fog  inso  \
# 1053      1111X      21.2(13)   12.0  NaN  77.0    0.0    3.0   5.6
# 1054      1111X      29.4(27)   15.0  NaN  81.0    0.0    2.0   3.2
# 1055      1111X  94.6(16/ene)  134.0  NaN  80.0    2.0   12.0   6.0
# 1056      1111X      16.6(04)   14.0  NaN  80.0    0.0    0.0   3.4
# 1057      1111X      45.2(22)   10.0  NaN  74.0    1.0    0.0   5.9
# 1058      1111X      94.6(16)   11.0  NaN  74.0    1.0    0.0   3.5
# 1059      1111X      17.0(11)   13.0  NaN  74.0    0.0    0.0   6.0
# 1060      1111X      10.5(23)   13.0  NaN  83.0    0.0    3.0   6.9
# 1061      1111X       9.7(29)   12.0  NaN  88.0    0.0    1.0   7.4
# 1062      1111X       8.2(23)   10.0  NaN  82.0    0.0    0.0   7.4
# 1063      1111X      14.0(11)   10.0  NaN  84.0    0.0    2.0   7.4
# 1064      1111X      60.2(11)    5.0  NaN  81.0    0.0    0.0   7.6
# 1065      1111X      17.8(26)    9.0  NaN  82.0    0.0    1.0   7.2
# ...

# %%
df_aemet_san_glo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 43 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   indicativo  39 non-null     int64
#  1   p_max       17 non-null     object
#  2   n_cub       17 non-null     float64
#  3   glo         30 non-null     float64
#  4   n_gra       17 non-null     float64
#  5   n_fog       17 non-null     float64
#  6   inso        17 non-null     float64
#  7   q_max       17 non-null     object
#  8   nw_55       15 non-null     float64
#  9   q_mar       17 non-null     float64
#  10  q_med       17 non-null     float64
#  11  tm_min      17 non-null     float64
#  12  ta_max      17 non-null     object
#  13  ts_min      17 non-null     float64
#  14  nt_30       17 non-null     float64
#  15  nv_0050     17 non-null     float64
#  16  n_des       17 non-null     float64
#  17  w_racha     15 non-null     object
# ...

# %%
df_aemet_raw.loc[df_aemet_raw["indicativo"] == '1111X']
# Out:
#      indicativo         p_max  n_cub  glo    hr  n_gra  n_fog  inso  \
# 1053      1111X      21.2(13)   12.0  NaN  77.0    0.0    3.0   5.6
# 1054      1111X      29.4(27)   15.0  NaN  81.0    0.0    2.0   3.2
# 1055      1111X  94.6(16/ene)  134.0  NaN  80.0    2.0   12.0   6.0
# 1056      1111X      16.6(04)   14.0  NaN  80.0    0.0    0.0   3.4
# 1057      1111X      45.2(22)   10.0  NaN  74.0    1.0    0.0   5.9
# 1058      1111X      94.6(16)   11.0  NaN  74.0    1.0    0.0   3.5
# 1059      1111X      17.0(11)   13.0  NaN  74.0    0.0    0.0   6.0
# 1060      1111X      10.5(23)   13.0  NaN  83.0    0.0    3.0   6.9
# 1061      1111X       9.7(29)   12.0  NaN  88.0    0.0    1.0   7.4
# 1062      1111X       8.2(23)   10.0  NaN  82.0    0.0    0.0   7.4
# 1063      1111X      14.0(11)   10.0  NaN  84.0    0.0    2.0   7.4
# 1064      1111X      60.2(11)    5.0  NaN  81.0    0.0    0.0   7.6
# 1065      1111X      17.8(26)    9.0  NaN  82.0    0.0    1.0   7.2
# ...

# %%
for elem in df_aemet_raw[df_aemet_raw["indicativo"] == '1111X'].index:
    print(elem, df_aemet_raw.loc[elem]["fecha"])
    #for i in df_aemet_san_glo.index:
    #fecha = df_aemet_raw.iloc[elem]["fecha"]
    #df_aemet_raw.loc[elem]["glo"] = df_aemet_san_glo[df_aemet_raw.loc[elem]["fecha"] == df_aemet_san_glo["fecha"]]["glo"]   
    print(df_aemet_san_glo[df_aemet_raw.loc[elem]["fecha"] == df_aemet_san_glo["fecha"]]["glo"] , df_aemet_raw.loc[elem]["glo"]) 
            #df_aemet_raw.iloc[elem]["glo"] = df_aemet_san_glo.iloc[i]["glo"]
   
    #elem["glo"] = df_aemet_san_glo[elem["fecha"] == df_aemet_san_glo["fecha"]]["glo"]
# Out:
# 1053 2023-10
# 0    29913.0
# Name: glo, dtype: float64 nan
# 1054 2023-11
# 1    15762.0
# Name: glo, dtype: float64 nan
# 1055 2023-13
# 3   NaN
# Name: glo, dtype: float64 nan
# 1056 2023-12
# 2   NaN
# Name: glo, dtype: float64 nan
# 1057 2023-2
# 4   NaN
# Name: glo, dtype: float64 nan
# 1058 2023-1
# 5    14315.0
# Name: glo, dtype: float64 nan
# 1059 2023-3
# 6    40408.0
# Name: glo, dtype: float64 nan
# 1060 2023-4
# 7    52955.0
# Name: glo, dtype: float64 nan
# 1061 2023-6
# 9    60083.0
# Name: glo, dtype: float64 nan
# 1062 2023-7
# 10    60476.0
# Name: glo, dtype: float64 nan
# 1063 2023-5
# 8    62832.0
# Name: glo, dtype: float64 nan
# 1064 2023-9
# 12    42069.0
# Name: glo, dtype: float64 nan
# 1065 2023-8
# 11    55108.0
# Name: glo, dtype: float64 nan
# 1066 2024-11
# 14    20986.0
# Name: glo, dtype: float64 nan
# 1067 2024-10
# 13   NaN
# Name: glo, dtype: float64 nan
# 1068 2024-12
# 15    15777.0
# Name: glo, dtype: float64 nan
# 1069 2024-1
# 17    18625.0
# ...

# %%
for elem in df_aemet_san_glo.index:
    print(df_aemet_san_glo.loc[elem]["fecha"])
    print(df_aemet_san_glo.loc[elem]["glo"])
    #print(df_aemet_raw[elem["fecha"] == df_aemet_raw["fecha"]])
    elem_glo = df_aemet_san_glo.loc[elem]["glo"]
    for aemet in df_aemet_raw[(df_aemet_raw["indicativo"] == '1111X') & (df_aemet_raw["fecha"] == df_aemet_san_glo.loc[elem]["fecha"])].index:
    #    df_aemet_raw.loc[aemet,3] = elem_glo
    #for i in df_aemet_san_glo.index:
    #fecha = df_aemet_raw.iloc[elem]["fecha"]
    #df_aemet_raw.loc[elem]["glo"] = df_aemet_san_glo[df_aemet_raw.loc[elem]["fecha"] == df_aemet_san_glo["fecha"]]["glo"]   
        print(df_aemet_san_glo.loc[elem]["glo"], " - " , df_aemet_raw.loc[aemet]["glo"]) 
            #df_aemet_raw.iloc[elem]["glo"] = df_aemet_san_glo.iloc[i]["glo"]
            
df_aemet_raw[df_aemet_raw["indicativo"] == '1111X'][["glo","fecha"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 2
#       1 for elem in df_aemet_san_glo:
# ----> 2     print(elem["fecha"])
#       3     print(df_aemet_san_glo.loc[elem]["fecha"])
#       4     print(df_aemet_san_glo.loc[elem]["glo"])
#
# TypeError: string indices must be integers, not 'str'

# %%
list_glo_san =[]
elem_glo_san =[]
for i in df_aemet_raw.index:
    if df_aemet_raw.iloc[i]["indicativo"] == "1111X":
        for j in df_aemet_san_glo.index:
            print(df_aemet_san_glo.iloc[j]["fecha"])
            print(df_aemet_raw.iloc[i]["fecha"])
            if df_aemet_san_glo.iloc[j]["fecha"] == df_aemet_raw.iloc[i]["fecha"]:
                elem_glo_san = df_aemet_san_glo.iloc[j]["glo"]
                print(elem_glo_san)
                df_aemet_raw[i]["glo"] = elem_glo_san
                list_glo_san.append(df_aemet_san_glo.iloc[j]["glo"])
            break
    else: list_glo_san.append(df_aemet_raw.loc[i]["glo"])
     
'''    
for elem in df_aemet_raw[df_aemet_raw["indicativo"] == '1111X'].index:
    print(elem, df_aemet_raw.loc[elem]["fecha"])
    #for i in df_aemet_san_glo.index:
    #fecha = df_aemet_raw.iloc[elem]["fecha"]
    #df_aemet_raw.loc[elem]["glo"] = df_aemet_san_glo[df_aemet_raw.loc[elem]["fecha"] == df_aemet_san_glo["fecha"]]["glo"]   
    print(df_aemet_san_glo[df_aemet_raw.loc[elem]["fecha"] == df_aemet_san_glo["fecha"]]["glo"] , df_aemet_raw.loc[elem]["glo"]) 
            #df_aemet_raw.iloc[elem]["glo"] = df_aemet_san_glo.iloc[i]["glo"]
            '''
# Out:
# 2023-10
# 2023-10
# 29913.0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\atosj\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1053
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
len(list_glo_san)
# Out:
# 1366

# %%
df_aemet_raw
# Out:
#      indicativo         p_max  n_cub       glo    hr  n_gra  n_fog  inso  \
# 0          1387      32.6(19)   11.0   28536.0  75.0    1.0    5.0   4.7
# 1          1387      36.4(05)   12.0   16599.0  80.0    0.0    3.0   3.0
# 2          1387      56.8(27)    8.0   14628.0  77.0    0.0    0.0   3.0
# 3          1387  56.8(27/dic)   83.0  533752.0  74.0    4.0   29.0   6.7
# 4          1387      22.0(19)   11.0   17949.0  76.0    1.0    0.0   3.9
# ...         ...           ...    ...       ...   ...    ...    ...   ...
# 1399       9434       8.0(03)    2.0       NaN  43.0    0.0    0.0  11.6
# 1400       9434      10.4(11)    1.0       NaN  46.0    0.0    0.0  11.8
# 1401       9434       7.8(27)    0.0       NaN  45.0    0.0    0.0  10.9
# 1402       9434      19.6(28)    2.0       NaN  53.0    0.0    0.0   9.5
# 1403       9434      12.4(05)    5.0       NaN  68.0    0.0    0.0   5.9
#
#                q_max  nw_55  ...  n_nie  tm_mes  tm_max nv_0100  ts_50  \
# ...

# %%
list_geo_id = []
for i in df_aemet_raw.index:
    match df_aemet_raw.loc[i]["indicativo"]:
        case "1387": list_geo_id.append(17)
        case "8178D": list_geo_id .append(7)
        case "6325O": list_geo_id .append(4)
        case "4478X": list_geo_id .append(16)
        case "0201D": list_geo_id .append(9)
        case "3469A": list_geo_id .append(16)
        case "5973": list_geo_id .append(4)
        case "4121": list_geo_id .append(7)
        case "5402": list_geo_id .append(4)
        case "5514": list_geo_id .append(4)
        case "4642E": list_geo_id .append(4)
        case "C430E": list_geo_id .append(19)
        case "2661": list_geo_id .append(8)
        case "9771C": list_geo_id .append(9)
        case "9170": list_geo_id .append(20)
        case "3194U": list_geo_id .append(13)
        case "6156X": list_geo_id .append(4)
        case "C639M": list_geo_id .append(19)
        case "5860E": list_geo_id .append(4)
        case "7178I": list_geo_id .append(21)
        case "1249X": list_geo_id .append(11)
        case "B228": list_geo_id .append(18)
        case "1549": list_geo_id .append(8)
        case "2462": list_geo_id .append(13)
        case "2867": list_geo_id .append(8)
        case "1024E": list_geo_id .append(10)
        case "1111": list_geo_id .append(6)        
        case "1111X": list_geo_id .append(6)
        case "2030": list_geo_id .append(8)
        case "C449C": list_geo_id .append(19)
        case "8368U": list_geo_id .append(5)
        case "3260B": list_geo_id .append(7)
        case "9981A": list_geo_id .append(9)
        case "8414A": list_geo_id .append(15)
        case "2422": list_geo_id .append(8)
        case "9434": list_geo_id .append(5)

# %%
len(list_geo_id)
# Out:
# 1404

# %%
df_aemet_raw["geo_id"] = list_geo_id

# %%
df_aemet_raw["Mes"] = df_aemet_raw["Mes"].astype(int)

# %%
df_aemet_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1404 entries, 0 to 1403
# Data columns (total 49 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   indicativo  1404 non-null   object
#  1   p_max       1296 non-null   object
#  2   n_cub       1059 non-null   float64
#  3   glo         1097 non-null   float64
#  4   hr          1241 non-null   float64
#  5   n_gra       998 non-null    float64
#  6   n_fog       998 non-null    float64
#  7   inso        1004 non-null   float64
#  8   q_max       1153 non-null   object
#  9   nw_55       1220 non-null   float64
#  10  q_mar       1152 non-null   float64
#  11  q_med       1154 non-null   float64
#  12  tm_min      1261 non-null   float64
#  13  ta_max      1261 non-null   object
#  14  ts_min      1261 non-null   float64
#  15  nt_30       1261 non-null   float64
#  16  nv_0050     938 non-null    float64
#  17  n_des       1059 non-null   float64
# ...

# %%
df_aemet_raw.head(10)
# Out:
#   indicativo         p_max  n_cub       glo    hr  n_gra  n_fog  inso  \
# 0       1387      32.6(19)   11.0   28536.0  75.0    1.0    5.0   4.7
# 1       1387      36.4(05)   12.0   16599.0  80.0    0.0    3.0   3.0
# 2       1387      56.8(27)    8.0   14628.0  77.0    0.0    0.0   3.0
# 3       1387  56.8(27/dic)   83.0  533752.0  74.0    4.0   29.0   6.7
# 4       1387      22.0(19)   11.0   17949.0  76.0    1.0    0.0   3.9
# 5       1387      11.2(24)    3.0   29027.0  67.0    2.0    1.0   6.9
# 6       1387      11.4(23)    8.0   40695.0  71.0    0.0    0.0   6.4
# 7       1387      12.2(13)    9.0   56159.0  73.0    0.0    1.0   7.9
# 8       1387       3.8(06)    4.0   72262.0  71.0    0.0    4.0   9.0
# 9       1387      17.8(17)    6.0   67183.0  79.0    0.0    7.0   9.0
#
#             q_max  nw_55  ...  tm_mes  tm_max  nv_0100 ts_50          q_min  \
# 0      1021.4(03)   13.0  ...    18.8    22.0      0.0  19.5      977.3(19)
# ...

# %%
df_solar["Mes"] = df_solar["Mes"].astype(int)

# %%
df_solar
# Out:
#      geo_id   Comunidad   Año  Mes  Energía Solar
# 0         4   Andalucía  2023    1      429269.28
# 1         4   Andalucía  2023    2      471628.41
# 2         4   Andalucía  2023    3      728490.93
# 3         4   Andalucía  2023    4      849844.87
# 4         4   Andalucía  2023    5      836786.21
# ..      ...         ...   ...  ...            ...
# 632      10  País Vasco  2025    7        8708.41
# 633      10  País Vasco  2025    8        7917.38
# 634      10  País Vasco  2025    9        6629.45
# 635      10  País Vasco  2025   10        5277.86
# 636      10  País Vasco  2025   11        2535.24
#
# [637 rows x 5 columns]

# %%
df_solar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 637 entries, 0 to 636
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   geo_id         637 non-null    int64
#  1   Comunidad      637 non-null    object
#  2   Año            637 non-null    object
#  3   Mes            637 non-null    int64
#  4   Energía Solar  637 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 25.0+ KB

# %%
df_aemet_raw.to_csv("../data/raw/AEMET/AEMET Datos anuales.csv")

# %%
#df_aemet_solar = pd.merge(df_aemet_raw,df_solar, on=["geo_id","Año","Mes"])
#df_aemet_solar = df_aemet_raw.join(df_solar,on=["geo_id","Año","Mes"])
df_aemet_solar = pd.merge(df_aemet_raw,df_solar, how='left', on=["geo_id","Año","Mes"])
df_aemet_solar
# Out:
#      indicativo         p_max  n_cub       glo    hr  n_gra  n_fog  inso  \
# 0          1387      32.6(19)   11.0   28536.0  75.0    1.0    5.0   4.7
# 1          1387      36.4(05)   12.0   16599.0  80.0    0.0    3.0   3.0
# 2          1387      56.8(27)    8.0   14628.0  77.0    0.0    0.0   3.0
# 3          1387  56.8(27/dic)   83.0  533752.0  74.0    4.0   29.0   6.7
# 4          1387      22.0(19)   11.0   17949.0  76.0    1.0    0.0   3.9
# ...         ...           ...    ...       ...   ...    ...    ...   ...
# 1399       9434       8.0(03)    2.0       NaN  43.0    0.0    0.0  11.6
# 1400       9434      10.4(11)    1.0       NaN  46.0    0.0    0.0  11.8
# 1401       9434       7.8(27)    0.0       NaN  45.0    0.0    0.0  10.9
# 1402       9434      19.6(28)    2.0       NaN  53.0    0.0    0.0   9.5
# 1403       9434      12.4(05)    5.0       NaN  68.0    0.0    0.0   5.9
#
#                q_max  nw_55  ...  nv_0100  ts_50          q_min np_010  \
# ...

# %%
df_aemet_solar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1260 entries, 0 to 1403
# Data columns (total 51 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   indicativo     1260 non-null   object
#  1   p_max          1229 non-null   object
#  2   n_cub          1011 non-null   float64
#  3   glo            1056 non-null   float64
#  4   hr             1181 non-null   float64
#  5   n_gra          951 non-null    float64
#  6   n_fog          951 non-null    float64
#  7   inso           952 non-null    float64
#  8   q_max          1092 non-null   object
#  9   nw_55          1163 non-null   float64
#  10  q_mar          1092 non-null   float64
#  11  q_med          1093 non-null   float64
#  12  tm_min         1195 non-null   float64
#  13  ta_max         1195 non-null   object
#  14  ts_min         1195 non-null   float64
#  15  nt_30          1195 non-null   float64
#  16  nv_0050        895 non-null    float64
# ...

# %%
df_aemet_solar.dropna(subset="Energía Solar", inplace=True)

# %%
df_aemet_solar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1260 entries, 0 to 1403
# Data columns (total 51 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   indicativo     1260 non-null   object
#  1   p_max          1229 non-null   object
#  2   n_cub          1011 non-null   float64
#  3   glo            1056 non-null   float64
#  4   hr             1181 non-null   float64
#  5   n_gra          951 non-null    float64
#  6   n_fog          951 non-null    float64
#  7   inso           952 non-null    float64
#  8   q_max          1092 non-null   object
#  9   nw_55          1163 non-null   float64
#  10  q_mar          1092 non-null   float64
#  11  q_med          1093 non-null   float64
#  12  tm_min         1195 non-null   float64
#  13  ta_max         1195 non-null   object
#  14  ts_min         1195 non-null   float64
#  15  nt_30          1195 non-null   float64
#  16  nv_0050        895 non-null    float64
# ...

# %%
df_aemet_solar.to_csv("../data/raw/pred_solar.csv")

# %%
df_aemet_solar
# Out:
#      indicativo     p_max  n_cub      glo    hr  n_gra  n_fog  inso  \
# 0          1387  32.6(19)   11.0  28536.0  75.0    1.0    5.0   4.7
# 1          1387  36.4(05)   12.0  16599.0  80.0    0.0    3.0   3.0
# 2          1387  56.8(27)    8.0  14628.0  77.0    0.0    0.0   3.0
# 10         1387   4.2(28)    3.0  75042.0  74.0    0.0    2.0   9.3
# 11         1387   3.8(26)    5.0  68298.0  75.0    0.0    2.0   9.4
# ...         ...       ...    ...      ...   ...    ...    ...   ...
# 1395       9434   8.6(07)    8.0      NaN  74.0    0.0    2.0   6.4
# 1396       9434  15.4(03)   17.0      NaN  71.0    0.0    1.0   4.9
# 1397       9434  13.6(25)    5.0      NaN  63.0    0.0    0.0   9.1
# 1398       9434   9.4(14)    3.0      NaN  51.0    0.0    0.0  10.9
# 1399       9434   8.0(03)    2.0      NaN  43.0    0.0    0.0  11.6
#
#            q_max  nw_55  ...  nv_0100  ts_50       q_min np_010    fecha  \
# 0     1021.4(03)   13.0  ...      0.0   19.5   977.3(19)   19.0  2023-10
# ...

# %%
df_aemet_solar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 864 entries, 0 to 1399
# Data columns (total 51 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   indicativo     864 non-null    object
#  1   p_max          845 non-null    object
#  2   n_cub          684 non-null    float64
#  3   glo            723 non-null    float64
#  4   hr             814 non-null    float64
#  5   n_gra          651 non-null    float64
#  6   n_fog          651 non-null    float64
#  7   inso           651 non-null    float64
#  8   q_max          751 non-null    object
#  9   nw_55          796 non-null    float64
#  10  q_mar          752 non-null    float64
#  11  q_med          752 non-null    float64
#  12  tm_min         823 non-null    float64
#  13  ta_max         823 non-null    object
#  14  ts_min         823 non-null    float64
#  15  nt_30          823 non-null    float64
#  16  nv_0050        609 non-null    float64
# ...

# %%
df_aemet_solar.describe()
# Out:
#             n_cub           glo          hr       n_gra       n_fog  \
# count  684.000000    723.000000  814.000000  651.000000  651.000000
# mean     6.595029  51755.937759   64.514742    0.274962    2.698925
# std      5.015762  23018.846521   14.352500    0.632190    4.174094
# min      0.000000  12835.000000   16.000000    0.000000    0.000000
# 25%      2.000000  30216.500000   56.000000    0.000000    0.000000
# 50%      6.000000  50440.000000   67.000000    0.000000    1.000000
# 75%     10.000000  74339.000000   76.000000    0.000000    4.000000
# max     25.000000  99977.000000   93.000000    4.000000   26.000000
#
#              inso       nw_55        q_mar        q_med      tm_min  ...  \
# count  651.000000  796.000000   752.000000   752.000000  823.000000  ...
# mean     7.728725    3.238693  1016.961303   966.735771   11.807655  ...
# std      2.802222    4.054759     4.247287    58.494285    6.285944  ...
# ...
